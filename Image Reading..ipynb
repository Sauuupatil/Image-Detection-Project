# %% [markdown]
# ### pip install opencv-python

# %%
import cv2

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
img=cv2.imread(r"D:\personal Document\india.jpg")

# %%
img
# Out:
# array([[[226, 225, 224],
#         [226, 225, 224],
#         [226, 225, 224],
#         ...,
#         [226, 225, 224],
#         [226, 225, 224],
#         [226, 225, 224]],
#
#        [[226, 225, 224],
#         [226, 225, 224],
#         [226, 225, 224],
#         ...,
#         [226, 225, 224],
#         [226, 225, 224],
#         [226, 225, 224]],
#
#        [[226, 225, 224],
#         [226, 225, 224],
#         [226, 225, 224],
#         ...,
#         [226, 225, 224],
#         [226, 225, 224],
#         [226, 225, 224]],
#
#        ...,
#
#        [[248, 217, 175],
#         [248, 217, 175],
#         [248, 217, 175],
#         ...,
#         [248, 217, 175],
#         [248, 217, 175],
#         [248, 217, 175]],
#
#        [[248, 217, 175],
#         [248, 217, 175],
#         [248, 217, 175],
#         ...,
#         [248, 217, 175],
#         [248, 217, 175],
#         [248, 217, 175]],
#
#        [[248, 217, 175],
#         [248, 217, 175],
#         [248, 217, 175],
# ...

# %%
img.shape
# Out:
# (704, 624, 3)

# %%
plt.imshow(img)

# %%
cv2.imshow("india_window",img)
cv2.waitKey(1)
# Out:
# -1

# %% [markdown]
# ### Gray_Scale

# %%
img
# Out:
# array([[[226, 225, 224],
#         [226, 225, 224],
#         [226, 225, 224],
#         ...,
#         [226, 225, 224],
#         [226, 225, 224],
#         [226, 225, 224]],
#
#        [[226, 225, 224],
#         [226, 225, 224],
#         [226, 225, 224],
#         ...,
#         [226, 225, 224],
#         [226, 225, 224],
#         [226, 225, 224]],
#
#        [[226, 225, 224],
#         [226, 225, 224],
#         [226, 225, 224],
#         ...,
#         [226, 225, 224],
#         [226, 225, 224],
#         [226, 225, 224]],
#
#        ...,
#
#        [[248, 217, 175],
#         [248, 217, 175],
#         [248, 217, 175],
#         ...,
#         [248, 217, 175],
#         [248, 217, 175],
#         [248, 217, 175]],
#
#        [[248, 217, 175],
#         [248, 217, 175],
#         [248, 217, 175],
#         ...,
#         [248, 217, 175],
#         [248, 217, 175],
#         [248, 217, 175]],
#
#        [[248, 217, 175],
#         [248, 217, 175],
#         [248, 217, 175],
# ...

# %%
img_gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

# %%
img_gray
# Out:
# array([[225, 225, 225, ..., 225, 225, 225],
#        [225, 225, 225, ..., 225, 225, 225],
#        [225, 225, 225, ..., 225, 225, 225],
#        ...,
#        [208, 208, 208, ..., 208, 208, 208],
#        [208, 208, 208, ..., 208, 208, 208],
#        [208, 208, 208, ..., 208, 208, 208]], dtype=uint8)

# %%
plt.imshow(img_gray)

# %%
cv2.imshow("gray_window",img_gray)
cv2.waitKey(1)
# Out:
# -1

# %% [markdown]
# ### Image Colours Changing

# %%
img.shape
# Out:
# (704, 624, 3)

# %%
img_gray.shape
# Out:
# (704, 624)

# %%
img_0 = img.copy()
img_1 = img.copy()
img_2 = img.copy()
img_3 = img.copy()

# %%
cv2.imshow("img_0 window",img_0)
cv2.waitKey(1)
# Out:
# -1

# %%
img_0.shape
# Out:
# (704, 624, 3)

# %%
img_0[:,:,0]=0

# %%
cv2.imshow("img_0 window",img_0)
cv2.waitKey(1)
# Out:
# -1

# %%
cv2.imshow("img_1 window",img_1)
cv2.waitKey(1)
# Out:
# -1

# %%
img_1[ : , : , 1]=0

# %%
cv2.imshow("img_1 window",img_1)
cv2.waitKey(1)
# Out:
# -1

# %%
cv2.imshow("Img_2 window", img_2)
cv2.waitKey(1)
# Out:
# -1

# %%
img_2[ : , : , 2]=0

# %%
cv2.imshow("Img_2 window", img_2)
cv2.waitKey(1)
# Out:
# -1

# %%
cv2.imshow("Img_3 window", img_3)
cv2.waitKey(1)
# Out:
# -1

# %%
img_3[ : , : , 2]=0

# %%
cv2.imshow("Img_3 window", img_3)
cv2.waitKey(1)
# Out:
# -1

# %%
img_stack = np.hstack((img_0,img_1,img_2,img_3))

# %%
cv2.imshow("img_stack" , img_stack)
cv2.waitKey(1)
# Out:
# -1

# %% [markdown]
#  ### Image Resize

# %%
img
# Out:
# array([[[226, 225, 224],
#         [226, 225, 224],
#         [226, 225, 224],
#         ...,
#         [226, 225, 224],
#         [226, 225, 224],
#         [226, 225, 224]],
#
#        [[226, 225, 224],
#         [226, 225, 224],
#         [226, 225, 224],
#         ...,
#         [226, 225, 224],
#         [226, 225, 224],
#         [226, 225, 224]],
#
#        [[226, 225, 224],
#         [226, 225, 224],
#         [226, 225, 224],
#         ...,
#         [226, 225, 224],
#         [226, 225, 224],
#         [226, 225, 224]],
#
#        ...,
#
#        [[248, 217, 175],
#         [248, 217, 175],
#         [248, 217, 175],
#         ...,
#         [248, 217, 175],
#         [248, 217, 175],
#         [248, 217, 175]],
#
#        [[248, 217, 175],
#         [248, 217, 175],
#         [248, 217, 175],
#         ...,
#         [248, 217, 175],
#         [248, 217, 175],
#         [248, 217, 175]],
#
#        [[248, 217, 175],
#         [248, 217, 175],
#         [248, 217, 175],
# ...

# %%
img.max()
# Out:
# 255

# %%
img.min()
# Out:
# 0

# %% [markdown]
# ### Scaling

# %%
img_scale=img/255.0

# %%
img_scale.min()
# Out:
# 0.0

# %%
img_scale.max()
# Out:
# 1.0

# %%
img
# Out:
# array([[[226, 225, 224],
#         [226, 225, 224],
#         [226, 225, 224],
#         ...,
#         [226, 225, 224],
#         [226, 225, 224],
#         [226, 225, 224]],
#
#        [[226, 225, 224],
#         [226, 225, 224],
#         [226, 225, 224],
#         ...,
#         [226, 225, 224],
#         [226, 225, 224],
#         [226, 225, 224]],
#
#        [[226, 225, 224],
#         [226, 225, 224],
#         [226, 225, 224],
#         ...,
#         [226, 225, 224],
#         [226, 225, 224],
#         [226, 225, 224]],
#
#        ...,
#
#        [[248, 217, 175],
#         [248, 217, 175],
#         [248, 217, 175],
#         ...,
#         [248, 217, 175],
#         [248, 217, 175],
#         [248, 217, 175]],
#
#        [[248, 217, 175],
#         [248, 217, 175],
#         [248, 217, 175],
#         ...,
#         [248, 217, 175],
#         [248, 217, 175],
#         [248, 217, 175]],
#
#        [[248, 217, 175],
#         [248, 217, 175],
#         [248, 217, 175],
# ...

# %%
img_scale
# Out:
# array([[[0.88627451, 0.88235294, 0.87843137],
#         [0.88627451, 0.88235294, 0.87843137],
#         [0.88627451, 0.88235294, 0.87843137],
#         ...,
#         [0.88627451, 0.88235294, 0.87843137],
#         [0.88627451, 0.88235294, 0.87843137],
#         [0.88627451, 0.88235294, 0.87843137]],
#
#        [[0.88627451, 0.88235294, 0.87843137],
#         [0.88627451, 0.88235294, 0.87843137],
#         [0.88627451, 0.88235294, 0.87843137],
#         ...,
#         [0.88627451, 0.88235294, 0.87843137],
#         [0.88627451, 0.88235294, 0.87843137],
#         [0.88627451, 0.88235294, 0.87843137]],
#
#        [[0.88627451, 0.88235294, 0.87843137],
#         [0.88627451, 0.88235294, 0.87843137],
#         [0.88627451, 0.88235294, 0.87843137],
#         ...,
#         [0.88627451, 0.88235294, 0.87843137],
#         [0.88627451, 0.88235294, 0.87843137],
#         [0.88627451, 0.88235294, 0.87843137]],
#
#        ...,
#
#        [[0.97254902, 0.85098039, 0.68627451],
# ...

# %%
cv2.imshow("Img_window", img)
cv2.waitKey(1)
# Out:
# -1

# %%
cv2.imshow("Img_scale_window", img_scale)
cv2.waitKey(1)
# Out:
# -1

# %% [markdown]
# ### Resize

# %%
cv2.imshow("Img_window", img)
cv2.waitKey(1)
# Out:
# -1

# %%
img.shape
# Out:
# (704, 624, 3)

# %%
img_resize = cv2.resize(img,(250,250))

# %%
cv2.imshow("img_resize_window",img_resize)
cv2.waitKey(1)
# Out:
# -1

# %%
img_large = cv2.resize(img,(700,850))

# %%
cv2.imshow("img_large_window",img_large)
cv2.waitKey(1)
# Out:
# -1

# %% [markdown]
# ### Image Save

# %%
cv2.imshow("Img_resize_window", img_resize)
cv2.waitKey(1)
# Out:
# -1

# %%
cv2.imwrite("img_small.jpg",img_resize)
# Out:
# True

# %%
cv2.imshow("Img_large_window", img_large)
cv2.waitKey(1)
# Out:
# -1

# %%
cv2.imwrite("img_large.jpg",img_large)
cv2.waitKey(1)
# Out:
# -1

# %%
cv2.imshow("Img_window", img)
cv2.waitKey(1)
# Out:
# -1

# %%
cv2.imwrite("ind_orginal_window.jpg",img)
cv2.waitKey(1)
# Out:
# -1

# %% [markdown]
# ###  Flip The Image

# %%
img
# Out:
# array([[[226, 225, 224],
#         [226, 225, 224],
#         [226, 225, 224],
#         ...,
#         [226, 225, 224],
#         [226, 225, 224],
#         [226, 225, 224]],
#
#        [[226, 225, 224],
#         [226, 225, 224],
#         [226, 225, 224],
#         ...,
#         [226, 225, 224],
#         [226, 225, 224],
#         [226, 225, 224]],
#
#        [[226, 225, 224],
#         [226, 225, 224],
#         [226, 225, 224],
#         ...,
#         [226, 225, 224],
#         [226, 225, 224],
#         [226, 225, 224]],
#
#        ...,
#
#        [[248, 217, 175],
#         [248, 217, 175],
#         [248, 217, 175],
#         ...,
#         [248, 217, 175],
#         [248, 217, 175],
#         [248, 217, 175]],
#
#        [[248, 217, 175],
#         [248, 217, 175],
#         [248, 217, 175],
#         ...,
#         [248, 217, 175],
#         [248, 217, 175],
#         [248, 217, 175]],
#
#        [[248, 217, 175],
#         [248, 217, 175],
#         [248, 217, 175],
# ...

# %%
cv2.imshow("Img_window", img)
cv2.waitKey(1)
# Out:
# -1

# %%
imgflip_0 = cv2.flip(img,0)

# %%
cv2.imshow("Img_flip0_window", imgflip_0)
cv2.waitKey(1)
# Out:
# -1

# %%
imgflip_1 = cv2.flip(img,1)

# %%
cv2.imshow("Img_flip1_window", imgflip_1)
cv2.waitKey(1)
# Out:
# -1

# %%
imgflip_negative = cv2.flip(img,-1)

# %%
cv2.imshow("Img_flip1_Negative_window", imgflip_negative)
cv2.waitKey(1)
# Out:
# -1

# %% [markdown]
# ### Cropping & Resize

# %%
img
# Out:
# array([[[226, 225, 224],
#         [226, 225, 224],
#         [226, 225, 224],
#         ...,
#         [226, 225, 224],
#         [226, 225, 224],
#         [226, 225, 224]],
#
#        [[226, 225, 224],
#         [226, 225, 224],
#         [226, 225, 224],
#         ...,
#         [226, 225, 224],
#         [226, 225, 224],
#         [226, 225, 224]],
#
#        [[226, 225, 224],
#         [226, 225, 224],
#         [226, 225, 224],
#         ...,
#         [226, 225, 224],
#         [226, 225, 224],
#         [226, 225, 224]],
#
#        ...,
#
#        [[248, 217, 175],
#         [248, 217, 175],
#         [248, 217, 175],
#         ...,
#         [248, 217, 175],
#         [248, 217, 175],
#         [248, 217, 175]],
#
#        [[248, 217, 175],
#         [248, 217, 175],
#         [248, 217, 175],
#         ...,
#         [248, 217, 175],
#         [248, 217, 175],
#         [248, 217, 175]],
#
#        [[248, 217, 175],
#         [248, 217, 175],
#         [248, 217, 175],
# ...

# %%
cv2.imshow("Img_window", img)
cv2.waitKey(1)
# Out:
# -1

# %%
img
# Out:
# array([[[226, 225, 224],
#         [226, 225, 224],
#         [226, 225, 224],
#         ...,
#         [226, 225, 224],
#         [226, 225, 224],
#         [226, 225, 224]],
#
#        [[226, 225, 224],
#         [226, 225, 224],
#         [226, 225, 224],
#         ...,
#         [226, 225, 224],
#         [226, 225, 224],
#         [226, 225, 224]],
#
#        [[226, 225, 224],
#         [226, 225, 224],
#         [226, 225, 224],
#         ...,
#         [226, 225, 224],
#         [226, 225, 224],
#         [226, 225, 224]],
#
#        ...,
#
#        [[248, 217, 175],
#         [248, 217, 175],
#         [248, 217, 175],
#         ...,
#         [248, 217, 175],
#         [248, 217, 175],
#         [248, 217, 175]],
#
#        [[248, 217, 175],
#         [248, 217, 175],
#         [248, 217, 175],
#         ...,
#         [248, 217, 175],
#         [248, 217, 175],
#         [248, 217, 175]],
#
#        [[248, 217, 175],
#         [248, 217, 175],
#         [248, 217, 175],
# ...

# %%
img.shape
# Out:
# (704, 624, 3)

# %%
img_crop = img [0:400 , 0:400]

# %%
cv2.imshow("Img_window", img)
cv2.waitKey(1)
# Out:
# -1

# %%
cv2.imshow("Img_crop_window", img_crop)
cv2.waitKey(1)
# Out:
# -1
